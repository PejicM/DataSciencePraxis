# %%
try:
    dbutils.fs.ls("/mnt/spark-data/")
    dbutils.fs.unmount("/mnt/spark-data/")
except:
    pass
finally: 
    dbutils.fs.mount("s3a://AKIAI26Y33OS6Q4RH3LA:z2gZ97yPG2SDDUdfhWP6RVaUonMyRRWb5wEuA5g9@datapao-spark","/mnt/spark-data/")

# %%
try:
  if dbutils.fs.ls("/mnt/spark-data/posts.csv")[0].name == 'posts.csv':
    print ( "You are all set up! :)" )
except e:
  print ("Oh no, something went wrong!")
  print (str(e))
